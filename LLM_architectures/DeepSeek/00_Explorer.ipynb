# %% [markdown]
# # As size increases, after a specific size it starts showing emergent behaviour.
# # To train a transformer:
# # pretraining and finetuning.
#
#
# # Pretraining : to understand language.
# # Finetuning: To give specific task context.
#
#
#
# # DeepSeek(open weights, )
# # v1 -> deepseek llm-> math, coder
# # v2 -> v2, v2 coder.
# # v3 - 671 B
# # R1 -  reasoning model (comparable to openAI , fraction of its cost)
#
#
# # Architecture
# ## Multi head latent attention
# ## MOE
# ## Multi token prediction
# ## Quantization
# ## RoPE
# # Training
# ## Reinforcement learning : GRPO (Rule based reward system.)
# # Optimization : using nvidia cuda/ptx optimizations.
# # Distiallation to smaller models for easy use.
#
# # Reference:
# ## reports: https://www.deepseek.com/en
# ## https://karthick.ai
# # https://www.youtube.com/@vizuara
# ## For CUDA : https://www.youtube.com/watch?v=86FAWCzIe_4
