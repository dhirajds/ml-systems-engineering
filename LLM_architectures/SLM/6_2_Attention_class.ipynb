# %% [markdown]
# # Attention class.
# ## Query : Current tokent the model focusses on .
# ## Key: each item in input sequence has a key.
# ## keys are used to match with query.
# ## use key and query to find the attention values.
# ## value: represents actual content reqpresenataion of the input items.
# ## based on attention weights, combine value to get context vector.

# %% [markdown]
# # Build a attention class.

# %%
class self
